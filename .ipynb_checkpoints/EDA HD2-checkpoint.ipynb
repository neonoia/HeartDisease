# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('data/tubes2_HeartDisease_train.csv')

# %%
df.head()
# Out:
#    Column1  Column2  Column3 Column4 Column5 Column6 Column7 Column8 Column9  \
# 0       54        1        4     125     216       0       0     140       0
# 1       55        1        4     158     217       0       0     110       1
# 2       54        0        3     135     304       1       0     170       0
# 3       48        0        3     120     195       0       0     125       0
# 4       50        1        4     120       0       0       1     156       1
#
#   Column10 Column11 Column12 Column13  Column14
# 0        0        ?        ?        ?         1
# 1      2.5        2        ?        ?         1
# 2        0        1        0        3         0
# 3        0        ?        ?        ?         0
# 4        0        1        ?        6         3

# %%
df.replace({"?":np.nan}, inplace=True)
print("Percentage of Empty in Each Attributes")
df.isnull().sum(axis = 0)/len(df)
# Out:
# Percentage of Empty in Each Attributes
# Column1     0.000000
# Column2     0.000000
# Column3     0.000000
# Column4     0.060334
# Column5     0.030809
# Column6     0.100128
# Column7     0.002567
# Column8     0.056483
# Column9     0.056483
# Column10    0.062901
# Column11    0.336329
# Column12    0.659820
# Column13    0.523748
# Column14    0.000000
# dtype: float64

# %%
df.drop(['Column12', 'Column13'], axis=1)
df.drop(df[pd.isnull(df['Column7'])].index, inplace=True)
df.drop(df[pd.isnull(df['Column5'])].index, inplace=True)
df.drop(df[pd.isnull(df['Column8'])].index, inplace=True)
df.drop(df[pd.isnull(df['Column9'])].index, inplace=True)
df.drop(df[pd.isnull(df['Column4'])].index, inplace=True)
df.drop(df[pd.isnull(df['Column10'])].index, inplace=True)
for column in df.columns:
    if (column == 'Column11'):
        df[column].fillna(df[column].mode()[0], inplace=True)
    else:
        df[column] = pd.to_numeric(df[column])
        #df[column].fillna(df[column].mode()[0], inplace=True)
        df[column].fillna(df[column].mean(), inplace=True)
        #df[column].fillna(df[column].median(), inplace=True)
df.describe(include='all')
# Out:
#            Column1     Column2     Column3     Column4     Column5  \
# count   704.000000  704.000000  704.000000  704.000000  704.000000
# unique         NaN         NaN         NaN         NaN         NaN
# top            NaN         NaN         NaN         NaN         NaN
# freq           NaN         NaN         NaN         NaN         NaN
# mean     53.255682    0.765625    3.274148  132.207386  202.805398
# std       9.384165    0.423909    0.925450   19.150067  108.706558
# min      28.000000    0.000000    1.000000    0.000000    0.000000
# 25%      46.000000    1.000000    3.000000  120.000000  179.750000
# 50%      54.000000    1.000000    4.000000  130.000000  228.000000
# 75%      60.000000    1.000000    4.000000  140.000000  270.000000
# max      77.000000    1.000000    4.000000  200.000000  529.000000
#
#            Column6     Column7     Column8     Column9    Column10 Column11  \
# count   704.000000  704.000000  704.000000  704.000000  704.000000      704
# unique         NaN         NaN         NaN         NaN         NaN        3
# top            NaN         NaN         NaN         NaN         NaN        2
# freq           NaN         NaN         NaN         NaN         NaN      480
# mean      0.142857    0.606534  138.427557    0.396307    4.037074      NaN
# std       0.331261    0.822868   26.017127    0.489477    7.894214      NaN
# min       0.000000    0.000000   60.000000    0.000000   -2.600000      NaN
# 25%       0.000000    0.000000  120.000000    0.000000    0.000000      NaN
# 50%       0.000000    0.000000  140.000000    0.000000    1.000000      NaN
# 75%       0.000000    1.000000  159.250000    1.000000    3.000000      NaN
# max       1.000000    2.000000  202.000000    1.000000   62.000000      NaN
#
#           Column12    Column13    Column14
# count   704.000000  704.000000  704.000000
# unique         NaN         NaN         NaN
# top            NaN         NaN         NaN
# freq           NaN         NaN         NaN
# mean      0.689394    5.013774    0.968750
# std       0.572646    1.381101    1.120933
# min       0.000000    3.000000    0.000000
# 25%       0.689394    5.013774    0.000000
# 50%       0.689394    5.013774    1.000000
# 75%       0.689394    6.000000    2.000000
# max       3.000000    7.000000    4.000000

# %%
#df = pd.get_dummies(data=df, columns=['Column3','Column7','Column11'])
pd.get_dummies(df, prefix=['Column3','Column7','Column11'], columns=['Column3','Column7','Column11'])
#df['Column11'].unique()
# Out:
#      Column1  Column2  Column4  Column5   Column6  Column8  Column9  Column10  \
# 0         54        1      125      216  0.000000      140        0       0.0
# 1         55        1      158      217  0.000000      110        1       2.5
# 2         54        0      135      304  1.000000      170        0       0.0
# 3         48        0      120      195  0.000000      125        0       0.0
# 4         50        1      120        0  0.000000      156        1       0.0
# 5         64        0      130      303  0.000000      122        0       2.0
# 6         63        1      130      308  0.000000      138        1       2.0
# 7         58        1      130      251  0.000000      110        0       0.0
# 8         42        1      150      268  0.000000      136        0       0.0
# 9         54        1      120      258  0.000000      147        0       4.0
# 10        58        1      115        0  0.142857      138        0       0.5
# 11        49        1      118      149  0.000000      126        0       8.0
# 12        61        1      142      200  1.000000      100        0       1.5
# 13        55        0      132      342  0.000000      166        0      12.0
# 14        60        1      132      218  0.000000      140        1       1.5
# 16        62        1      160        0  0.000000       72        1       0.0
# 17        57        1      150      276  0.000000      112        1       6.0
# 18        43        1      120      291  0.000000      155        0       0.0
# 19        67        1      125      254  1.000000      163        0       2.0
# 20        59        1      110        0  0.142857       94        0       0.0
# 21        45        0      112      160  0.000000      138        0       0.0
# 22        51        1      135      160  0.000000      150        0       2.0
# 23        53        1      120      246  0.000000      116        1       0.0
# 24        51        0      120      295  0.000000      157        0       6.0
# 26        64        0      180      325  0.000000      154        1       0.0
# 27        52        1      108      233  1.000000      147        0       1.0
# 28        41        1      104        0  0.000000      111        0       0.0
# 29        55        1      140      201  0.000000      130        1       3.0
# 31        58        0      100      248  0.000000      122        0       1.0
# 32        44        1      130      215  0.000000      135        0       0.0
# ..       ...      ...      ...      ...       ...      ...      ...       ...
# 743       43        1      150      247  0.000000      171        0      15.0
# 744       64        1      110      211  0.000000      144        1      18.0
# 745       42        1      120      295  0.000000      162        0       0.0
# 746       34        1      150      214  0.000000      168        0       0.0
# 747       39        1      130      307  0.000000      140        0       0.0
# 748       38        0      105        0  0.142857      166        0       2.8
# 749       49        0      130      207  0.000000      135        0       0.0
# 750       32        1      110      225  0.000000      184        0       0.0
# 751       57        1      154      232  0.000000      164        0       0.0
# 752       74        1      155      310  0.000000      112        1       1.5
# 753       59        1      150      212  1.000000      157        0      16.0
# 754       53        1      130        0  0.000000      135        1       1.0
# 16            0
# 17            0
# 18            0
# 19            0
# 20            0
# 21            0
# 22            0
# 23            0
# 24            0
# 26            0
# 27            0
# 28            0
# 29            0
# 31            0
# 32            0
# ..          ...
# 743           0
# 744           0
# 745           0
# 746           0
# 747           0
# 748           0
# 749           0
# 750           0
# 751           0
# 752           1
# 753           0
# 754           0
# 755           0
# 756           0
# 758           0
# 759           0
# 760           0
# 761           0
# 762           0
# 763           0
# 764           0
# 765           1
# 766           0
# 767           0
# 768           0
# 770           0
# 772           0
# 773           0
# 774           1
# 776           0
#
# [704 rows x 21 columns]

# %%
from sklearn.preprocessing import StandardScaler
cols = ['Column1','Column2','Column3','Column4','Column5','Column6','Column7','Column8','Column9','Column10','Column11','Column12','Column13',]
cols_to_norm = ['Column1','Column4','Column5','Column8','Column10']
df[cols_to_norm] = StandardScaler().fit_transform(df[cols_to_norm])
#df.describe()
#df['Column10'].unique()

# %%
import seaborn as sns

f, ax = plt.subplots(figsize=(10, 8))
corr = df.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax)

# %%
#df.drop(['Column4', 'Column7_2'], axis=1)

# %%
y = df['Column14']
X = df.drop(['Column14'], axis=1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=123)

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn import tree
dt = tree.DecisionTreeClassifier()
dt.fit(X_train, y_train)
dt_pred = dt.predict(X_test)

# %%
print('Accuracy : ' + str(accuracy_score(y_test, dt_pred)))
print(classification_report(y_test,dt_pred))
# Out:
# Accuracy : 0.5319148936170213
#              precision    recall  f1-score   support
#
#           0       0.77      0.60      0.67        72
#           1       0.56      0.55      0.55        44
#           2       0.12      0.22      0.15         9
#           3       0.29      0.43      0.34        14
#           4       0.00      0.00      0.00         2
#
# avg / total       0.60      0.53      0.56       141

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()
gnb.fit(X_train, y_train)
gnb_pred = gnb.predict(X_test)

# %%
print('Accuracy : ' + str(accuracy_score(y_test, gnb_pred)))
print(classification_report(y_test,gnb_pred))
# Out:
# Accuracy : 0.6170212765957447
#              precision    recall  f1-score   support
#
#           0       0.81      0.78      0.79        72
#           1       0.57      0.59      0.58        44
#           2       0.29      0.44      0.35         9
#           3       0.17      0.07      0.10        14
#           4       0.00      0.00      0.00         2
#
# avg / total       0.63      0.62      0.62       141

# %% [markdown]
# ## kNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
train_acc = []
test_acc  = []
for k in range(1,100):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    train_acc.append(knn.score(X_train ,y_train))
    test_acc.append(knn.score(X_test ,y_test))

# %%
plt.plot(train_acc)
plt.plot(test_acc)

# %%
knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(X_train, y_train)
knn_pred = knn.predict(X_test)

# %%
print('Accuracy : ' + str(accuracy_score(y_test, knn_pred)))
print(classification_report(y_test,knn_pred))
# Out:
# Accuracy : 0.6312056737588653
#              precision    recall  f1-score   support
#
#           0       0.77      0.88      0.82        72
#           1       0.49      0.52      0.51        44
#           2       0.12      0.11      0.12         9
#           3       0.50      0.14      0.22        14
#           4       0.00      0.00      0.00         2
#
# avg / total       0.60      0.63      0.61       141
# /home/budiman/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ## MLPC

# %%
from sklearn.neural_network import MLPClassifier

# %%
mlpc = MLPClassifier(solver='lbfgs', hidden_layer_sizes=(112,), random_state=1, max_iter=1000)
mlpc.fit(X_train, y_train)
mlpc_pred = mlpc.predict(X_test)

# %%
print('Accuracy : ' + str(accuracy_score(y_test, mlpc_pred)))
print(classification_report(y_test,mlpc_pred))
# Out:
# Accuracy : 0.524822695035461
#              precision    recall  f1-score   support
#
#           0       0.75      0.69      0.72        72
#           1       0.48      0.48      0.48        44
#           2       0.09      0.11      0.10         9
#           3       0.18      0.14      0.16        14
#           4       0.00      0.00      0.00         2
#
# avg / total       0.55      0.52      0.54       141
